# %% [markdown]
# Preparation:
# - git load ipyleaflet, geopandas, leafmap
# - install only once

# %%
# %%bash
#
# #Matplotlib,Pillow,Pandas,Mamba,Geopandas,Geemap,Leafmap
# #sudo pip install protobuf-compiler
# apt install -y protobuf-compiler
# pip -q install shapely
# pip -q install geopy
# pip -q install matplotlib
# pip -q install pillow
# pip -q install xyzservices
# pip -q install pandas
# pip -q install mamba
# pip -q install jupyter_contrib_nbextensions
# pip -q install geopandas
# pip -q install keplergl
# pip -q install python-Levenshtein
#
# #jupyter nbextension install --py --symlink --sys-prefix ipyleaflet
# #jupyter nbextension enable --py --sys-prefix ipyleaflet
#
# #jupyter labextension install @jupyter-widgets/jupyterlab-manager jupyter-leaflet
#
# pip -q install ipywidgets
# pip -q install geemap xarray_leaflet
# pip -q install -U geemap
# pip -q install leafmap
# pip -q install -U leafmap
# Out:
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper

# %% [markdown]
# First excercise: Show me New York with leafmap as a hybrid google map at a zoom of 12 and with a height of 450px and a width of 800px and finally a maximum zoom of 20.

# %%
print('Starting first leafmap test...')

import leafmap
#center to New York at 41 degrees north and 74 degrees west
m = leafmap.Map(google_map="HYBRID",center=[40.702557, -74.012318], zoom=12,height="450px", width="800px",max_zoom="20")  #center=[lat, lon]
#show
m
# Out:
# Starting first leafmap test...
# Map(center=[40.702557, -74.012318], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Second Excercise: Parse available yellow and green taxi dataset to a variable by streaming and preserve all information from the csv. Use a class, type hints and multithreading. Make sure the data is available and show the min-max-timeframe where your data is available. Prepare adjustment for time ranges that skip already loaded tables. For testing print minimum and maximum available pickup time.

# %% [markdown]
# Show available file types for taxis and the minimum and maximum pickup times found:

# %%
import read_taxidata

print('Starting first leafmap test...')
td = read_taxidata.TaxiData('/home/benjamin-elias/Proseminar/Jupyterlab/taxi_data/')
here_files = td.get_date_files(2021, 3)
print(here_files)
td.load_add_available(here_files)
print('Minimum time available:')
print(td.get_minimum_available_pickup_time())
print('Maximum time available:')
print(td.get_maximum_available_pickup_time())
# Out:
# Starting first leafmap test...
# {'yellow': [datetime.datetime(2021, 3, 1, 0, 0)], 'green': [datetime.datetime(2021, 3, 1, 0, 0)]}
# Minimum time available:
# 2020-01-01 00:00:00
# Maximum time available:
# 2021-07-31 23:59:58

# %% [markdown]
# Third Excercise: Parse the taxi zone lookup. Keep it forever.

# %%
import read_taxizone

tz = read_taxizone.TaxiZone('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/taxi_data/taxi+_zone_lookup.csv')
print('Printing zone 29:')
print(tz.get_from_location_id(29))
print('Printing neighbourhood Windsor Terrace:')
print(tz.get_from_neighborhood_name('Windsor Terrace'))
# Out:
# Printing zone 29:
# (29, 'Brooklyn', 'Brighton Beach', 'Boro Zone')
# Printing neighbourhood Windsor Terrace:
# (257, 'Brooklyn', 'Windsor Terrace', 'Boro Zone')

# %% [markdown]
# Fourth Excercise: Add the Neighbourhoods layer to the map.

# %%
import leafmap
#center to New York at 41 degrees north and 74 degrees west
m = leafmap.Map(google_map="HYBRID",center=[40.702557, -74.012318], zoom=12,height="600px", width="1200px",max_zoom="20")  #center=[lat, lon]
#show
print('Showing current layer names before adding neighbourhoods:')
print(m.get_layer_names())
print('Add geojson layer neighbourhoods:')
m.add_geojson('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/nyc-neighborhoods.geo.json', layer_name='neighbourhoods', style={}, hover_style={}, style_callback=None, fill_colors=['red'], info_mode='on_hover')
m.layer_opacity('neighbourhoods', 0.3)
print(m.get_layer_names())
m
# Out:
# Showing current layer names before adding neighbourhoods:
# ['OpenStreetMap', 'Google Satellite']
# Add geojson layer neighbourhoods:
# ['OpenStreetMap', 'Google Satellite', 'neighbourhoods']
# Map(center=[40.702557, -74.012318], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Fifth Excercise: Fill all neighbourhoods with random colors and add again.

# %%
import leafmap
import random
from typing import List
#center to New York at 41 degrees north and 74 degrees west
m = leafmap.Map(google_map="HYBRID",center=[40.702557, -74.012318], zoom=12,height="600px", width="1200px",max_zoom="20")  #center=[lat, lon]
#show
print('Showing current layer names before adding neighbourhoods:')
print(m.get_layer_names())
print('Random color hex:')
r = lambda: random.randint(0,255)
print('#%02X%02X%02X' % (r(),r(),r()))
print('Random color hex list:')
color_list: List[str] = []
for i in range(0, len(tz.zones)):
    color_list.append('#%02X%02X%02X' % (r(), r(), r()))
print('Add geojson layer neighbourhoods, color is sorted by geojson polygon order:')
m.add_geojson('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/nyc-neighborhoods.geo.json', layer_name='neighbourhoods', style={}, hover_style={}, style_callback=None, fill_colors=color_list, info_mode='on_hover')
m.layer_opacity('neighbourhoods', 0.3)
print(m.get_layer_names())
m
# Out:
# Showing current layer names before adding neighbourhoods:
# ['OpenStreetMap', 'Google Satellite']
# Random color hex:
# #67789F
# Random color hex list:
# Add geojson layer neighbourhoods, color is sorted by geojson polygon order:
# ['OpenStreetMap', 'Google Satellite', 'neighbourhoods']
# Map(center=[40.702557, -74.012318], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Sixth Excercise: Manually parse the Neighbourhoods layer and calculate the central pinpoint of each, show the pinpoints on the map and oriented on that the neighbourhood name. Make sure you are able to connect the taxi zone information with the geojson for nyc neighborhoods. Maybe correct the taxi zones and use Levenshtein distance to estimate the correct target names first.

# %% [markdown]
# First we show how to find the correct taxi zone for each neighborhood. Remind yourself that there are less neighborhoods than taxizones, so that the taxi zones are pretty detailed and cover only one neighborhood. In the end of the first scan not all taxi zones will be used. To have a good filtering system we should scan the geojson with the taxi zones now to make a double join of data.

# %%
from read_neighbourhoods import NeighbourhoodTaxiData
nd = NeighbourhoodTaxiData('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/nyc-neighborhoods.geo.json')
# Out:
# Multiple found: Williamsburg
# {(217, 'Brooklyn', 'South Williamsburg', 'Boro Zone'), (256, 'Brooklyn', 'Williamsburg (South Side)', 'Boro Zone'), (80, 'Brooklyn', 'East Williamsburg', 'Boro Zone'), (255, 'Brooklyn', 'Williamsburg/Williamsburg (North)', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (255, 'Brooklyn', 'Williamsburg/Williamsburg (North)', 'Boro Zone')
#
# Multiple found: South Williamsburg
# {(217, 'Brooklyn', 'South Williamsburg', 'Boro Zone'), (255, 'Brooklyn', 'Williamsburg/Williamsburg (North)', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (217, 'Brooklyn', 'South Williamsburg', 'Boro Zone')
#
# Multiple found: East Williamsburg
# {(80, 'Brooklyn', 'East Williamsburg', 'Boro Zone'), (255, 'Brooklyn', 'Williamsburg/Williamsburg (North)', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (80, 'Brooklyn', 'East Williamsburg', 'Boro Zone')
#
# Multiple found: Downtown Brooklyn-DUMBO-Boerum Hill
# {(66, 'Brooklyn', 'DUMBO/Vinegar Hill', 'Boro Zone'), (65, 'Brooklyn', 'Downtown Brooklyn/MetroTech', 'Boro Zone'), (25, 'Brooklyn', 'Boerum Hill', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (65, 'Brooklyn', 'Downtown Brooklyn/MetroTech', 'Boro Zone')
#
# Not really found: Bushwick (West)
# Estimated this very alike information instead on the taxi lookup table:
# (36, 'Brooklyn', 'Bushwick North (West)', 'Boro Zone')
#
# Not really found: Bushwick (East)
# Estimated this very alike information instead on the taxi lookup table:
# (37, 'Brooklyn', 'Bushwick South (East)/The Evergreens Cemetery', 'Boro Zone')
#
# Multiple found: East New York (North)
# {(76, 'Brooklyn', 'East New York/New Lots/City Line', 'Boro Zone'), (77, 'Brooklyn', 'East New York (North)/Pennsylvania Avenue', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (77, 'Brooklyn', 'East New York (North)/Pennsylvania Avenue', 'Boro Zone')
#
# Multiple found: Highland Park-Cypress Hills Cemeteries (South)
# {(96, 'Queens', 'Forest Park/Highland Park', 'Boro Zone'), (102, 'Queens', 'Glendale/Highland Park', 'Boro Zone'), (63, 'Brooklyn', 'Cypress Hills', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (96, 'Queens', 'Forest Park/Highland Park', 'Boro Zone')
#
# Multiple found: Carroll Gardens-Cobble Hill-Gowanus-Red Hook
# {(195, 'Brooklyn', 'Red Hook', 'Boro Zone'), (40, 'Brooklyn', 'Carroll Gardens', 'Boro Zone'), (52, 'Brooklyn', 'Cobble Hill', 'Boro Zone'), (106, 'Brooklyn', 'Gowanus', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (40, 'Brooklyn', 'Carroll Gardens', 'Boro Zone')
#
# Not really found: Sunset Park (Central)
# Estimated this very alike information instead on the taxi lookup table:
# (228, 'Brooklyn', 'Sunset Park West (Central)', 'Boro Zone')
#
# Not really found: Prospect Lefferts Gardens-Wingate
# Estimated this very alike information instead on the taxi lookup table:
# (188, 'Brooklyn', 'Prospect-Lefferts Gardens', 'Boro Zone')
#
# Not really found: Dyker Beach Park
# Estimated this very alike information instead on the taxi lookup table:
# (67, 'Brooklyn', 'Dyker Heights/Fort Hamilton', 'Boro Zone')
#
# Multiple found: Bensonhurst
# {(22, 'Brooklyn', 'Bensonhurst West', 'Boro Zone'), (21, 'Brooklyn', 'Bensonhurst East', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (22, 'Brooklyn', 'Bensonhurst West', 'Boro Zone')
#
# Multiple found: Mapleton-Midwood (West)
# {(178, 'Brooklyn', 'Ocean Parkway South/Midwood/Mapleton (West)', 'Boro Zone'), (165, 'Brooklyn', 'Midwood', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (178, 'Brooklyn', 'Ocean Parkway South/Midwood/Mapleton (West)', 'Boro Zone')
#
# Multiple found: Flatbush
# {(72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone'), (89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone'), (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone')
#
# Multiple found: Midwood
# {(178, 'Brooklyn', 'Ocean Parkway South/Midwood/Mapleton (West)', 'Boro Zone'), (165, 'Brooklyn', 'Midwood', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (178, 'Brooklyn', 'Ocean Parkway South/Midwood/Mapleton (West)', 'Boro Zone')
#
# Multiple found: Gravesend (East)-Homecrest
# {(123, 'Brooklyn', 'Homecrest', 'Boro Zone'), (108, 'Brooklyn', 'Gravesend/Calvert Vaux Park', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (123, 'Brooklyn', 'Homecrest', 'Boro Zone')
#
# Multiple found: Madison
# {(186, 'Manhattan', 'Penn Station/Madison Sqare West/Midtown South', 'Yellow Zone'), (149, 'Brooklyn', 'Madison', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (149, 'Brooklyn', 'Madison', 'Boro Zone')
#
# Multiple found: Sheepshead Bay-Manhattan Beach-Gerritsen Beach
# {(150, 'Brooklyn', 'Manhattan Beach', 'Boro Zone'), (210, 'Brooklyn', 'Sheepshead Bay', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (150, 'Brooklyn', 'Manhattan Beach', 'Boro Zone')
#
# Multiple found: East Flatbush-Erasmus
# {(89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone'), (85, 'Brooklyn', 'Erasmus', 'Boro Zone'), (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')
#
# Multiple found: East Flatbush-Farragut
# {(89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone'), (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')
#
# Multiple found: East Flatbush-Rugby
# {(72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone'), (89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone'), (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone')
#
# Multiple found: East Flatbush-Remsen Village
# {(72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone'), (89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone'), (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone')
#
# Multiple found: Marine Park-Mill Basin-Bergen Beach
# {(154, 'Brooklyn', 'Marine Park/Floyd Bennett Field/Mc Guire Fields', 'Boro Zone'), (155, 'Brooklyn', 'Marine Park/Mill Basin/Plumb Island', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (154, 'Brooklyn', 'Marine Park/Floyd Bennett Field/Mc Guire Fields', 'Boro Zone')
#
# Multiple found: Marine Park-Plumb Island
# {(154, 'Brooklyn', 'Marine Park/Floyd Bennett Field/Mc Guire Fields', 'Boro Zone'), (155, 'Brooklyn', 'Marine Park/Mill Basin/Plumb Island', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (155, 'Brooklyn', 'Marine Park/Mill Basin/Plumb Island', 'Boro Zone')
#
# Not really found: McGuire Fields
# Estimated this very alike information instead on the taxi lookup table:
# (154, 'Brooklyn', 'Marine Park/Floyd Bennett Field/Mc Guire Fields', 'Boro Zone')
#
# Multiple found: Jamaica Bay (West)
# {(2, 'Queens', 'Jamaica Bay', 'Boro Zone'), (130, 'Queens', 'Jamaica', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (2, 'Queens', 'Jamaica Bay', 'Boro Zone')
#
# Not really found: North & South Brother Islands
# Estimated this very alike information instead on the taxi lookup table:
# (199, 'Bronx', 'Rikers Island/North and South Brother Islands', 'Boro Zone')
#
# Multiple found: Crotona Park East
# {(60, 'Bronx', 'Crotona Park East', 'Boro Zone'), (59, 'Bronx', 'Crotona Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (60, 'Bronx', 'Crotona Park East', 'Boro Zone')
#
# Multiple found: Crotona Park
# {(60, 'Bronx', 'Crotona Park East', 'Boro Zone'), (59, 'Bronx', 'Crotona Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (59, 'Bronx', 'Crotona Park', 'Boro Zone')
#
# Multiple found: Concourse-Concourse Village
# {(69, 'Bronx', 'East Concourse/Concourse Village', 'Boro Zone'), (167, 'Bronx', 'Morrisania/Concourse Village/Yankee Stadium/Macombs Dam Park', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (69, 'Bronx', 'East Concourse/Concourse Village', 'Boro Zone')
#
# Multiple found: Highbridge
# {(119, 'Bronx', 'Highbridge', 'Boro Zone'), (120, 'Manhattan', 'Highbridge Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (119, 'Bronx', 'Highbridge', 'Boro Zone')
#
# Multiple found: West Farms
# {(32, 'Bronx', 'Bronxdale/West Farms', 'Boro Zone'), (248, 'Bronx', 'West Farms/Bronx River', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (32, 'Bronx', 'Bronxdale/West Farms', 'Boro Zone')
#
# Multiple found: Bedford Park
# {(17, 'Brooklyn', 'Bedford', 'Boro Zone'), (18, 'Bronx', 'Bedford Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (18, 'Bronx', 'Bedford Park', 'Boro Zone')
#
# Multiple found: Kingsbridge Heights-Van Cortlandt Village
# {(136, 'Bronx', 'Kingsbridge Heights', 'Boro Zone'), (220, 'Bronx', 'Spuyten Duyvil/Kingsbridge', 'Boro Zone'), (241, 'Bronx', 'Van Cortlandt Village', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (241, 'Bronx', 'Van Cortlandt Village', 'Boro Zone')
#
# Multiple found: Kingsbridge-Marble Hill
# {(153, 'Manhattan', 'Marble Hill', 'Boro Zone'), (220, 'Bronx', 'Spuyten Duyvil/Kingsbridge', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (153, 'Manhattan', 'Marble Hill', 'Boro Zone')
#
# Multiple found: Riverdale-Spuyten Duyvil
# {(200, 'Bronx', 'Riverdale/North Riverdale/Fieldston', 'Boro Zone'), (220, 'Bronx', 'Spuyten Duyvil/Kingsbridge', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (220, 'Bronx', 'Spuyten Duyvil/Kingsbridge', 'Boro Zone')
#
# Multiple found: Soundview-Bruckner-Bronx River
# {(248, 'Bronx', 'West Farms/Bronx River', 'Boro Zone'), (213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone'), (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (248, 'Bronx', 'West Farms/Bronx River', 'Boro Zone')
#
# Multiple found: Soundview-Clason Point
# {(213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone'), (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')
#
# Multiple found: Castle Hill-Unionport
# {(250, 'Bronx', 'Westchester Village/Unionport', 'Boro Zone'), (213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone')
#
# Multiple found: Soundview Park
# {(213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone'), (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')
#
# Not really found: Westchester Square
# Estimated this very alike information instead on the taxi lookup table:
# (250, 'Bronx', 'Westchester Village/Unionport', 'Boro Zone')
#
# Multiple found: Pelham Bay-Country Club-City Island
# {(183, 'Bronx', 'Pelham Bay', 'Boro Zone'), (58, 'Bronx', 'Country Club', 'Boro Zone'), (46, 'Bronx', 'City Island/Hard Island', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (58, 'Bronx', 'Country Club', 'Boro Zone')
#
# Not really found: Co-op City
# Estimated this very alike information instead on the taxi lookup table:
# (51, 'Bronx', 'Co-Op City', 'Boro Zone')
#
# Not really found: Hart Island
# Estimated this very alike information instead on the taxi lookup table:
# (46, 'Bronx', 'City Island/Hard Island', 'Boro Zone')
#
# Multiple found: Pelham Parkway-Van Nest
# {(242, 'Bronx', 'Van Nest/Morris Park', 'Boro Zone'), (185, 'Bronx', 'Pelham Parkway/Hutchison Metro Center', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (185, 'Bronx', 'Pelham Parkway/Hutchison Metro Center', 'Boro Zone')
#
# Not really found: Hutchinson Metro Center
# Estimated this very alike information instead on the taxi lookup table:
# (185, 'Bronx', 'Pelham Parkway/Hutchison Metro Center', 'Boro Zone')
#
# Multiple found: Pelham Bay Park
# {(183, 'Bronx', 'Pelham Bay', 'Boro Zone'), (184, 'Bronx', 'Pelham Bay Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (184, 'Bronx', 'Pelham Bay Park', 'Boro Zone')
#
# Multiple found: Financial District-Battery Park City
# {(13, 'Manhattan', 'Battery Park City', 'Yellow Zone'), (12, 'Manhattan', 'Battery Park', 'Yellow Zone'), (209, 'Manhattan', 'Seaport/Financial District/Battery Park City', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (209, 'Manhattan', 'Seaport/Financial District/Battery Park City', 'Yellow Zone')
#
# Multiple found: The Battery-Governors Island-Ellis Island-Liberty Island
# {(105, 'Manhattan', 'Liberty Island', 'Yellow Zone'), (104, 'Manhattan', 'Ellis Island', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (105, 'Manhattan', 'Liberty Island', 'Yellow Zone')
#
# Multiple found: SoHo-Little Italy-Hudson Square
# {(144, 'Manhattan', 'Little Italy/NoLiTa', 'Yellow Zone'), (211, 'Manhattan', 'SoHo', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (144, 'Manhattan', 'Little Italy/NoLiTa', 'Yellow Zone')
#
# Multiple found: Greenwich Village
# {(114, 'Manhattan', 'Greenwich Village South', 'Yellow Zone'), (113, 'Manhattan', 'Greenwich Village North', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (114, 'Manhattan', 'Greenwich Village South', 'Yellow Zone')
#
# Multiple found: West Village
# {(249, 'Manhattan', 'West Village', 'Yellow Zone'), (158, 'Manhattan', 'Meatpacking/West Village West', 'Yellow Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (249, 'Manhattan', 'West Village', 'Yellow Zone')
#
# Multiple found: Chinatown-Two Bridges
# {(232, 'Manhattan', 'Two Bridges/Seward Park', 'Yellow Zone'), (45, 'Manhattan', 'Chinatown', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (232, 'Manhattan', 'Two Bridges/Seward Park', 'Yellow Zone')
#
# Multiple found: East Village
# {(79, 'Manhattan', 'East Village', 'Yellow Zone'), (4, 'Manhattan', 'Alphabet City/East Village', 'Yellow Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (79, 'Manhattan', 'East Village', 'Yellow Zone')
#
# Multiple found: Chelsea-Hudson Yards
# {(68, 'Manhattan', 'East Chelsea/Hudson Yards', 'Yellow Zone'), (246, 'Manhattan', 'West Chelsea/Hudson Yards', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (68, 'Manhattan', 'East Chelsea/Hudson Yards', 'Yellow Zone')
#
# Not really found: Hell's Kitchen
# Estimated this very alike information instead on the taxi lookup table:
# (239, 'Manhattan', 'Upper West Side South/Hell’s Kitchen', 'Yellow Zone')
#
# Multiple found: Midtown South-Flatiron-Union Square
# {(164, 'Manhattan', 'Midtown South', 'Yellow Zone'), (186, 'Manhattan', 'Penn Station/Madison Sqare West/Midtown South', 'Yellow Zone'), (261, 'Manhattan', 'World Trade Center/Midtown South', 'Yellow Zone'), (90, 'Manhattan', 'Flatiron', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (164, 'Manhattan', 'Midtown South', 'Yellow Zone')
#
# Multiple found: Midtown-Times Square
# {(230, 'Manhattan', 'Times Sq/Theatre District', 'Yellow Zone'), (163, 'Manhattan', 'Midtown North/Times Square', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (163, 'Manhattan', 'Midtown North/Times Square', 'Yellow Zone')
#
# Multiple found: Murray Hill-Kips Bay
# {(170, 'Manhattan', 'Murray Hill', 'Yellow Zone'), (137, 'Manhattan', 'Kips Bay', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (170, 'Manhattan', 'Murray Hill', 'Yellow Zone')
#
# Multiple found: United Nations
# {(233, 'Manhattan', 'United Nations/Turtle Bay South', 'Yellow Zone'), (237, 'Manhattan', 'Upper East Side South/East Midtown/Turtle Bay/United Nations', 'Yellow Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (233, 'Manhattan', 'United Nations/Turtle Bay South', 'Yellow Zone')
#
# Not really found: Upper West Side (Central)
# Estimated this very alike information instead on the taxi lookup table:
# (24, 'Manhattan', 'Bloomingdale/Upper West Side North', 'Yellow Zone')
#
# Multiple found: Harlem (South)
# {(50, 'Manhattan', 'Clinton West/East Harlem (South)', 'Yellow Zone'), (75, 'Manhattan', 'East Harlem South', 'Boro Zone'), (41, 'Manhattan', 'Central Harlem (South)', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (50, 'Manhattan', 'Clinton West/East Harlem (South)', 'Yellow Zone')
#
# Multiple found: Harlem (North)
# {(42, 'Manhattan', 'Central Harlem North', 'Boro Zone'), (74, 'Manhattan', 'East Harlem North', 'Boro Zone'), (48, 'Manhattan', 'Clinton East/East Harlem (North)', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (74, 'Manhattan', 'East Harlem North', 'Boro Zone')
#
# Multiple found: East Harlem (South)
# {(75, 'Manhattan', 'East Harlem South', 'Boro Zone'), (50, 'Manhattan', 'Clinton West/East Harlem (South)', 'Yellow Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (50, 'Manhattan', 'Clinton West/East Harlem (South)', 'Yellow Zone')
#
# Multiple found: East Harlem (North)
# {(74, 'Manhattan', 'East Harlem North', 'Boro Zone'), (48, 'Manhattan', 'Clinton East/East Harlem (North)', 'Yellow Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (48, 'Manhattan', 'Clinton East/East Harlem (North)', 'Yellow Zone')
#
# Not really found: Randall's Island
# Estimated this very alike information instead on the taxi lookup table:
# (194, 'Manhattan', 'Randalls Island', 'Yellow Zone')
#
# Multiple found: Inwood
# {(128, 'Manhattan', 'Inwood Hill Park', 'Boro Zone'), (127, 'Manhattan', 'Inwood', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (127, 'Manhattan', 'Inwood', 'Boro Zone')
#
# Multiple found: Highbridge Park
# {(119, 'Bronx', 'Highbridge', 'Boro Zone'), (120, 'Manhattan', 'Highbridge Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (120, 'Manhattan', 'Highbridge Park', 'Boro Zone')
#
# Multiple found: Inwood Hill Park
# {(128, 'Manhattan', 'Inwood Hill Park', 'Boro Zone'), (127, 'Manhattan', 'Inwood', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (128, 'Manhattan', 'Inwood Hill Park', 'Boro Zone')
#
# Multiple found: Astoria (North)-Ditmars-Steinway
# {(223, 'Queens', 'Steinway', 'Boro Zone'), (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')
#
# Multiple found: Old Astoria-Hallets Point
# {(179, 'Queens', 'Old Astoria', 'Boro Zone'), (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (179, 'Queens', 'Old Astoria', 'Boro Zone')
#
# Multiple found: Astoria (East)-Woodside (North)
# {(260, 'Queens', 'Woodside/Calvary/Mount Zion Cemeteries', 'Boro Zone'), (207, 'Queens', 'Saint Michaels Cemetery/Woodside', 'Boro Zone'), (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (260, 'Queens', 'Woodside/Calvary/Mount Zion Cemeteries', 'Boro Zone')
#
# Not really found: St. Michael's Cemetery
# Estimated this very alike information instead on the taxi lookup table:
# (207, 'Queens', 'Saint Michaels Cemetery/Woodside', 'Boro Zone')
#
# Multiple found: Astoria Park
# {(8, 'Queens', 'Astoria Park', 'Boro Zone'), (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (8, 'Queens', 'Astoria Park', 'Boro Zone')
#
# Multiple found: Long Island City-Hunters Point
# {(145, 'Queens', 'Long Island City/Hunters Point', 'Boro Zone'), (146, 'Queens', 'Long Island City/Queens Plaza', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (145, 'Queens', 'Long Island City/Hunters Point', 'Boro Zone')
#
# Multiple found: Woodside
# {(260, 'Queens', 'Woodside/Calvary/Mount Zion Cemeteries', 'Boro Zone'), (207, 'Queens', 'Saint Michaels Cemetery/Woodside', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (260, 'Queens', 'Woodside/Calvary/Mount Zion Cemeteries', 'Boro Zone')
#
# Multiple found: East Elmhurst
# {(70, 'Queens', 'East Elmhurst', 'Boro Zone'), (83, 'Queens', 'Elmhurst/Maspeth', 'Boro Zone'), (82, 'Queens', 'Elmhurst', 'Boro Zone'), (138, 'Queens', 'LaGuardia Airport/East Elmhurst', 'Airports')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (70, 'Queens', 'East Elmhurst', 'Boro Zone')
#
# Multiple found: North Corona
# {(173, 'Queens', 'North Corona', 'Boro Zone'), (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone'), (57, 'Queens', 'Corona', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (173, 'Queens', 'North Corona', 'Boro Zone')
#
# Multiple found: Elmhurst
# {(70, 'Queens', 'East Elmhurst', 'Boro Zone'), (83, 'Queens', 'Elmhurst/Maspeth', 'Boro Zone'), (82, 'Queens', 'Elmhurst', 'Boro Zone'), (138, 'Queens', 'LaGuardia Airport/East Elmhurst', 'Airports')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (83, 'Queens', 'Elmhurst/Maspeth', 'Boro Zone')
#
# Multiple found: Corona
# {(93, 'Queens', 'Flushing Meadows-Corona Park/Mount Hebron/Cedar Grove Cemeteries', 'Boro Zone'), (173, 'Queens', 'North Corona', 'Boro Zone'), (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone'), (57, 'Queens', 'Corona', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone')
#
# Multiple found: Maspeth
# {(157, 'Queens', 'Maspeth/Mount Olivet/All Faiths Cemeteries', 'Boro Zone'), (83, 'Queens', 'Elmhurst/Maspeth', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (157, 'Queens', 'Maspeth/Mount Olivet/All Faiths Cemeteries', 'Boro Zone')
#
# Multiple found: Highland Park-Cypress Hills Cemeteries (North)
# {(96, 'Queens', 'Forest Park/Highland Park', 'Boro Zone'), (102, 'Queens', 'Glendale/Highland Park', 'Boro Zone'), (63, 'Brooklyn', 'Cypress Hills', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (96, 'Queens', 'Forest Park/Highland Park', 'Boro Zone')
#
# Multiple found: Murray Hill-Broadway Flushing
# {(92, 'Queens', 'Flushing', 'Boro Zone'), (170, 'Manhattan', 'Murray Hill', 'Yellow Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (170, 'Manhattan', 'Murray Hill', 'Yellow Zone')
#
# Multiple found: East Flushing
# {(73, 'Queens', 'East Flushing/Kissena Park', 'Boro Zone'), (92, 'Queens', 'Flushing', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (73, 'Queens', 'East Flushing/Kissena Park', 'Boro Zone')
#
# Multiple found: Flushing-Willets Point
# {(92, 'Queens', 'Flushing', 'Boro Zone'), (253, 'Queens', 'Willets Point', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (253, 'Queens', 'Willets Point', 'Boro Zone')
#
# Multiple found: Kew Gardens Hills
# {(134, 'Queens', 'Kew Gardens', 'Boro Zone'), (135, 'Queens', 'Kew Gardens Hills', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (135, 'Queens', 'Kew Gardens Hills', 'Boro Zone')
#
# Multiple found: Fresh Meadows-Utopia
# {(98, 'Queens', 'Fresh Meadows', 'Boro Zone'), (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (98, 'Queens', 'Fresh Meadows', 'Boro Zone')
#
# Multiple found: Jamaica Estates-Holliswood
# {(131, 'Queens', 'Jamaica Estates', 'Boro Zone'), (130, 'Queens', 'Jamaica', 'Boro Zone'), (122, 'Queens', 'Hollis', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (131, 'Queens', 'Jamaica Estates', 'Boro Zone')
#
# Multiple found: Jamaica Hills-Briarwood
# {(130, 'Queens', 'Jamaica', 'Boro Zone'), (28, 'Queens', 'Briarwood/Jamaica Hills', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (28, 'Queens', 'Briarwood/Jamaica Hills', 'Boro Zone')
#
# Multiple found: Kew Gardens
# {(134, 'Queens', 'Kew Gardens', 'Boro Zone'), (135, 'Queens', 'Kew Gardens Hills', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (134, 'Queens', 'Kew Gardens', 'Boro Zone')
#
# Multiple found: South Ozone Park
# {(180, 'Queens', 'Ozone Park', 'Boro Zone'), (216, 'Queens', 'South Ozone Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (216, 'Queens', 'South Ozone Park', 'Boro Zone')
#
# Multiple found: Ozone Park
# {(180, 'Queens', 'Ozone Park', 'Boro Zone'), (216, 'Queens', 'South Ozone Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (180, 'Queens', 'Ozone Park', 'Boro Zone')
#
# Multiple found: Oakland Gardens-Hollis Hills
# {(175, 'Queens', 'Oakland Gardens/Cunningham Park', 'Boro Zone'), (122, 'Queens', 'Hollis', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (175, 'Queens', 'Oakland Gardens/Cunningham Park', 'Boro Zone')
#
# Multiple found: Jamaica
# {(131, 'Queens', 'Jamaica Estates', 'Boro Zone'), (28, 'Queens', 'Briarwood/Jamaica Hills', 'Boro Zone'), (130, 'Queens', 'Jamaica', 'Boro Zone'), (215, 'Queens', 'South Jamaica', 'Boro Zone'), (2, 'Queens', 'Jamaica Bay', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (130, 'Queens', 'Jamaica', 'Boro Zone')
#
# Multiple found: South Jamaica
# {(215, 'Queens', 'South Jamaica', 'Boro Zone'), (130, 'Queens', 'Jamaica', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (215, 'Queens', 'South Jamaica', 'Boro Zone')
#
# Not really found: Springfield Gardens (North)-Rochdale Village
# Estimated this very alike information instead on the taxi lookup table:
# (218, 'Queens', 'Springfield Gardens North', 'Boro Zone')
#
# Not really found: St. Albans
# Estimated this very alike information instead on the taxi lookup table:
# (205, 'Queens', 'Saint Albans', 'Boro Zone')
#
# Not really found: Springfield Gardens (South)-Brookville
# Estimated this very alike information instead on the taxi lookup table:
# (219, 'Queens', 'Springfield Gardens South', 'Boro Zone')
#
# Not really found: Montefiore Cemetery
# Estimated this very alike information instead on the taxi lookup table:
# (72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone')
#
# Multiple found: Breezy Point-Belle Harbor-Rockaway Park-Broad Channel
# {(27, 'Queens', 'Breezy Point/Fort Tilden/Riis Beach', 'Boro Zone'), (30, 'Queens', 'Broad Channel', 'Boro Zone'), (201, 'Queens', 'Rockaway Park', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (30, 'Queens', 'Broad Channel', 'Boro Zone')
#
# Not really found: Rockaway Community Park
# Estimated this very alike information instead on the taxi lookup table:
# (201, 'Queens', 'Rockaway Park', 'Boro Zone')
#
# Multiple found: Flushing Meadows-Corona Park
# {(92, 'Queens', 'Flushing', 'Boro Zone'), (93, 'Queens', 'Flushing Meadows-Corona Park/Mount Hebron/Cedar Grove Cemeteries', 'Boro Zone'), (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone'), (57, 'Queens', 'Corona', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (93, 'Queens', 'Flushing Meadows-Corona Park/Mount Hebron/Cedar Grove Cemeteries', 'Boro Zone')
#
# Not really found: John F. Kennedy International Airport
# Estimated this very alike information instead on the taxi lookup table:
# (132, 'Queens', 'JFK Airport', 'Airports')
#
# Multiple found: Jamaica Bay (East)
# {(2, 'Queens', 'Jamaica Bay', 'Boro Zone'), (130, 'Queens', 'Jamaica', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (2, 'Queens', 'Jamaica Bay', 'Boro Zone')
#
# Multiple found: Tompkinsville-Stapleton-Clifton-Fox Hills
# {(221, 'Staten Island', 'Stapleton', 'Boro Zone'), (115, 'Staten Island', 'Grymes Hill/Clifton', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (221, 'Staten Island', 'Stapleton', 'Boro Zone')
#
# Not really found: Rosebank-Shore Acres-Park Hill
# Estimated this very alike information instead on the taxi lookup table:
# (13, 'Manhattan', 'Battery Park City', 'Yellow Zone')
#
# Multiple found: West New Brighton-Silver Lake-Grymes Hill
# {(206, 'Staten Island', 'Saint George/New Brighton', 'Boro Zone'), (115, 'Staten Island', 'Grymes Hill/Clifton', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (206, 'Staten Island', 'Saint George/New Brighton', 'Boro Zone')
#
# Not really found: Mariner's Harbor-Arlington-Graniteville
# Estimated this very alike information instead on the taxi lookup table:
# (156, 'Staten Island', 'Mariners Harbor', 'Boro Zone')
#
# Not really found: Snug Harbor
# Estimated this very alike information instead on the taxi lookup table:
# (64, 'Queens', 'Douglaston/Little Neck/Alley Pond Park', 'Boro Zone')
#
# Multiple found: Grasmere-Arrochar-South Beach-Dongan Hills
# {(6, 'Staten Island', 'Arrochar/Fort Wadsworth', 'Boro Zone'), (214, 'Staten Island', 'South Beach/Dongan Hills', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (214, 'Staten Island', 'South Beach/Dongan Hills', 'Boro Zone')
#
# Multiple found: Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights
# {(118, 'Staten Island', 'Heartland Village/Todt Hill', 'Boro Zone'), (23, 'Staten Island', 'Bloomfield/Emerson Hill', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (23, 'Staten Island', 'Bloomfield/Emerson Hill', 'Boro Zone')
#
# Not really found: New Springville-Willowbrook-Bulls Head-Travis
# Estimated this very alike information instead on the taxi lookup table:
# (218, 'Queens', 'Springfield Gardens North', 'Boro Zone')
#
# Multiple found: Great Kills-Eltingville
# {(84, 'Staten Island', "Eltingville/Annadale/Prince's Bay", 'Boro Zone'), (109, 'Staten Island', 'Great Kills', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (84, 'Staten Island', "Eltingville/Annadale/Prince's Bay", 'Boro Zone')
#
# Multiple found: Arden Heights-Rossville
# {(5, 'Staten Island', 'Arden Heights', 'Boro Zone'), (204, 'Staten Island', 'Rossville/Woodrow', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (5, 'Staten Island', 'Arden Heights', 'Boro Zone')
#
# Multiple found: Annadale-Huguenot-Prince's Bay-Woodrow
# {(84, 'Staten Island', "Eltingville/Annadale/Prince's Bay", 'Boro Zone'), (204, 'Staten Island', 'Rossville/Woodrow', 'Boro Zone')}
# Estimated this very alike information instead on the taxi lookup table:
# (84, 'Staten Island', "Eltingville/Annadale/Prince's Bay", 'Boro Zone')
#
# Not really found: Hoffman & Swinburne Islands
# Estimated this very alike information instead on the taxi lookup table:
# (46, 'Bronx', 'City Island/Hard Island', 'Boro Zone')
#
# Not really found: Miller Field
# Estimated this very alike information instead on the taxi lookup table:
# (19, 'Queens', 'Bellerose', 'Boro Zone')
#
# Multiple found: Great Kills Park
# {(109, 'Staten Island', 'Great Kills', 'Boro Zone'), (110, 'Staten Island', 'Great Kills Park', 'Boro Zone')}
# Length analysis showed that this should be correct on the input taxi lookup table:
# (110, 'Staten Island', 'Great Kills Park', 'Boro Zone')
#
# Draw Newark Airport to outer New York.
# Double joined missing tuple (4, 'Manhattan', 'Alphabet City/East Village', 'Yellow Zone') to the neighborhood East Village
# Double joined missing tuple (12, 'Manhattan', 'Battery Park', 'Yellow Zone') to the neighborhood Battery Park City
# Double joined missing tuple (21, 'Brooklyn', 'Bensonhurst East', 'Boro Zone') to the neighborhood Bensonhurst
# Double joined missing tuple (25, 'Brooklyn', 'Boerum Hill', 'Boro Zone') to the neighborhood Boerum Hill
# Double joined missing tuple (41, 'Manhattan', 'Central Harlem (South)', 'Boro Zone') to the neighborhood East Harlem (South)
# Double joined missing tuple (42, 'Manhattan', 'Central Harlem North', 'Boro Zone') to the neighborhood East Harlem (North)
# Double joined missing tuple (45, 'Manhattan', 'Chinatown', 'Yellow Zone') to the neighborhood Chinatown
# Double joined missing tuple (52, 'Brooklyn', 'Cobble Hill', 'Boro Zone') to the neighborhood Cobble Hill
# Double joined missing tuple (54, 'Brooklyn', 'Columbia Street/Carrol Gardens', 'Boro Zone') to the neighborhood Carroll Gardens
# Double joined missing tuple (57, 'Queens', 'Corona', 'Boro Zone') to the neighborhood Corona
# Double joined missing tuple (66, 'Brooklyn', 'DUMBO/Vinegar Hill', 'Boro Zone') to the neighborhood DUMBO
# Double joined missing tuple (75, 'Manhattan', 'East Harlem South', 'Boro Zone') to the neighborhood East Harlem (South)
# Double joined missing tuple (82, 'Queens', 'Elmhurst', 'Boro Zone') to the neighborhood Elmhurst
# Double joined missing tuple (85, 'Brooklyn', 'Erasmus', 'Boro Zone') to the neighborhood Erasmus
# Double joined missing tuple (87, 'Manhattan', 'Financial District North', 'Yellow Zone') to the neighborhood Financial District
# Double joined missing tuple (88, 'Manhattan', 'Financial District South', 'Yellow Zone') to the neighborhood Financial District
# Double joined missing tuple (90, 'Manhattan', 'Flatiron', 'Yellow Zone') to the neighborhood Flatiron
# Double joined missing tuple (92, 'Queens', 'Flushing', 'Boro Zone') to the neighborhood Flushing
# Double joined missing tuple (94, 'Bronx', 'Fordham South', 'Boro Zone') to the neighborhood Fordham Heights
# Double joined missing tuple (100, 'Manhattan', 'Garment District/Midtown Center', 'Yellow Zone') to the neighborhood Midtown South
# Double joined missing tuple (103, 'Manhattan', "Governor's Island", 'Yellow Zone') to the neighborhood Governors Island
# Double joined missing tuple (104, 'Manhattan', 'Ellis Island', 'Yellow Zone') to the neighborhood Ellis Island
# Double joined missing tuple (106, 'Brooklyn', 'Gowanus', 'Boro Zone') to the neighborhood Gowanus
# Double joined missing tuple (109, 'Staten Island', 'Great Kills', 'Boro Zone') to the neighborhood Great Kills
# Double joined missing tuple (113, 'Manhattan', 'Greenwich Village North', 'Yellow Zone') to the neighborhood Greenwich Village
# Double joined missing tuple (115, 'Staten Island', 'Grymes Hill/Clifton', 'Boro Zone') to the neighborhood Clifton
# Double joined missing tuple (118, 'Staten Island', 'Heartland Village/Todt Hill', 'Boro Zone') to the neighborhood Todt Hill
# Double joined missing tuple (125, 'Manhattan', 'Hudson Sqare', 'Yellow Zone') to the neighborhood Hudson Square
# Double joined missing tuple (136, 'Bronx', 'Kingsbridge Heights', 'Boro Zone') to the neighborhood Kingsbridge Heights
# Double joined missing tuple (137, 'Manhattan', 'Kips Bay', 'Yellow Zone') to the neighborhood Kips Bay
# Double joined missing tuple (140, 'Manhattan', 'Lenox Hill East', 'Yellow Zone') to the neighborhood Lenox Hill
# Double joined missing tuple (141, 'Manhattan', 'Lenox Hill West', 'Yellow Zone') to the neighborhood Lenox Hill
# Double joined missing tuple (142, 'Manhattan', 'Lincoln Square East', 'Yellow Zone') to the neighborhood Lincoln Square
# Double joined missing tuple (143, 'Manhattan', 'Lincoln Square West', 'Yellow Zone') to the neighborhood Lincoln Square
# Double joined missing tuple (146, 'Queens', 'Long Island City/Queens Plaza', 'Boro Zone') to the neighborhood Long Island City
# Double joined missing tuple (158, 'Manhattan', 'Meatpacking/West Village West', 'Yellow Zone') to the neighborhood West Village
# Double joined missing tuple (161, 'Manhattan', 'Midtown Center', 'Yellow Zone') to the neighborhood Midtown South
# Double joined missing tuple (162, 'Manhattan', 'Midtown East', 'Yellow Zone') to the neighborhood Midtown South
# Double joined missing tuple (165, 'Brooklyn', 'Midwood', 'Boro Zone') to the neighborhood Midwood (West)
# Double joined missing tuple (171, 'Queens', 'Murray Hill-Queens', 'Boro Zone') to the neighborhood Murray Hill
# Double joined missing tuple (183, 'Bronx', 'Pelham Bay', 'Boro Zone') to the neighborhood Pelham Bay
# Double joined missing tuple (186, 'Manhattan', 'Penn Station/Madison Sqare West/Midtown South', 'Yellow Zone') to the neighborhood Midtown South
# Double joined missing tuple (195, 'Brooklyn', 'Red Hook', 'Boro Zone') to the neighborhood Red Hook
# Double joined missing tuple (200, 'Bronx', 'Riverdale/North Riverdale/Fieldston', 'Boro Zone') to the neighborhood Riverdale
# Double joined missing tuple (204, 'Staten Island', 'Rossville/Woodrow', 'Boro Zone') to the neighborhood Rossville
# Double joined missing tuple (210, 'Brooklyn', 'Sheepshead Bay', 'Boro Zone') to the neighborhood Sheepshead Bay
# Double joined missing tuple (211, 'Manhattan', 'SoHo', 'Yellow Zone') to the neighborhood SoHo
# Double joined missing tuple (223, 'Queens', 'Steinway', 'Boro Zone') to the neighborhood Steinway
# Double joined missing tuple (225, 'Brooklyn', 'Stuyvesant Heights', 'Boro Zone') to the neighborhood Stuyvesant (West)
# Double joined missing tuple (227, 'Brooklyn', 'Sunset Park East', 'Boro Zone') to the neighborhood Sunset Park (East)
# Double joined missing tuple (229, 'Manhattan', 'Sutton Place/Turtle Bay North', 'Yellow Zone') to the neighborhood Turtle Bay
# Double joined missing tuple (230, 'Manhattan', 'Times Sq/Theatre District', 'Yellow Zone') to the neighborhood Times Square
# Double joined missing tuple (234, 'Manhattan', 'Union Sqare', 'Yellow Zone') to the neighborhood Union Square
# Double joined missing tuple (245, 'Staten Island', 'West Brighton', 'Boro Zone') to the neighborhood New Brighton
# Double joined missing tuple (246, 'Manhattan', 'West Chelsea/Hudson Yards', 'Yellow Zone') to the neighborhood Hudson Yards
# Double joined missing tuple (247, 'Bronx', 'West Concourse', 'Boro Zone') to the neighborhood Concourse
# Double joined missing tuple (256, 'Brooklyn', 'Williamsburg (South Side)', 'Boro Zone') to the neighborhood Williamsburg
# Double joined missing tuple (261, 'Manhattan', 'World Trade Center/Midtown South', 'Yellow Zone') to the neighborhood Midtown South
# Double joined missing tuple (262, 'Manhattan', 'Yorkville East', 'Yellow Zone') to the neighborhood Yorkville
# Double joined missing tuple (263, 'Manhattan', 'Yorkville West', 'Yellow Zone') to the neighborhood Yorkville

# %% [markdown]
# Since the last step we have two lists within NeighborhoodData. Those are the following list of tuples where the index references to another list of polygon lists (that cannot be printed because of size):

# %%
for n in nd.neighbourhoodTuples:
    print(n)
# Out:
# (112, 'Brooklyn', 'Greenpoint', 'Boro Zone')
# (255, 'Brooklyn', 'Williamsburg/Williamsburg (North)', 'Boro Zone')
# (217, 'Brooklyn', 'South Williamsburg', 'Boro Zone')
# (80, 'Brooklyn', 'East Williamsburg', 'Boro Zone')
# (33, 'Brooklyn', 'Brooklyn Heights', 'Boro Zone')
# (65, 'Brooklyn', 'Downtown Brooklyn/MetroTech', 'Boro Zone')
# (97, 'Brooklyn', 'Fort Greene', 'Boro Zone')
# (49, 'Brooklyn', 'Clinton Hill', 'Boro Zone')
# (34, 'Brooklyn', 'Brooklyn Navy Yard', 'Boro Zone')
# (17, 'Brooklyn', 'Bedford', 'Boro Zone')
# (36, 'Brooklyn', 'Bushwick North (West)', 'Boro Zone')
# (37, 'Brooklyn', 'Bushwick South (East)/The Evergreens Cemetery', 'Boro Zone')
# (63, 'Brooklyn', 'Cypress Hills', 'Boro Zone')
# (77, 'Brooklyn', 'East New York (North)/Pennsylvania Avenue', 'Boro Zone')
# (76, 'Brooklyn', 'East New York/New Lots/City Line', 'Boro Zone')
# (222, 'Brooklyn', 'Starrett City/Shirley Chisholm State Park', 'Boro Zone')
# (96, 'Queens', 'Forest Park/Highland Park', 'Boro Zone')
# (40, 'Brooklyn', 'Carroll Gardens', 'Boro Zone')
# (181, 'Brooklyn', 'Park Slope', 'Boro Zone')
# (257, 'Brooklyn', 'Windsor Terrace', 'Boro Zone')
# (228, 'Brooklyn', 'Sunset Park West (Central)', 'Boro Zone')
# (111, 'Brooklyn', 'Green-Wood Cemetery', 'Boro Zone')
# (189, 'Brooklyn', 'Prospect Heights', 'Boro Zone')
# (61, 'Brooklyn', 'Crown Heights North', 'Boro Zone')
# (62, 'Brooklyn', 'Crown Heights South/Lincoln Terrace Park', 'Boro Zone')
# (188, 'Brooklyn', 'Prospect-Lefferts Gardens', 'Boro Zone')
# (14, 'Brooklyn', 'Bay Ridge', 'Boro Zone')
# (67, 'Brooklyn', 'Dyker Heights/Fort Hamilton', 'Boro Zone')
# (22, 'Brooklyn', 'Bensonhurst West', 'Boro Zone')
# (11, 'Brooklyn', 'Bath Beach', 'Boro Zone')
# (108, 'Brooklyn', 'Gravesend/Calvert Vaux Park', 'Boro Zone')
# (26, 'Brooklyn', 'Borough Park', 'Boro Zone')
# (133, 'Brooklyn', 'Kensington', 'Boro Zone')
# (178, 'Brooklyn', 'Ocean Parkway South/Midwood/Mapleton (West)', 'Boro Zone')
# (55, 'Brooklyn', 'Coney Island', 'Boro Zone')
# (29, 'Brooklyn', 'Brighton Beach', 'Boro Zone')
# (89, 'Brooklyn', 'Flatbush/Ditmas Park', 'Boro Zone')
# (123, 'Brooklyn', 'Homecrest', 'Boro Zone')
# (149, 'Brooklyn', 'Madison', 'Boro Zone')
# (150, 'Brooklyn', 'Manhattan Beach', 'Boro Zone')
# (177, 'Brooklyn', 'Ocean Hill', 'Boro Zone')
# (35, 'Brooklyn', 'Brownsville', 'Boro Zone')
# (71, 'Brooklyn', 'East Flatbush/Farragut', 'Boro Zone')
# (72, 'Brooklyn', 'East Flatbush-Rugby/Remsen Village/Holy Cross Cemetery', 'Boro Zone')
# (91, 'Brooklyn', 'Flatlands', 'Boro Zone')
# (154, 'Brooklyn', 'Marine Park/Floyd Bennett Field/Mc Guire Fields', 'Boro Zone')
# (39, 'Brooklyn', 'Canarsie', 'Boro Zone')
# (155, 'Brooklyn', 'Marine Park/Mill Basin/Plumb Island', 'Boro Zone')
# (190, 'Brooklyn', 'Prospect Park', 'Boro Zone')
# (2, 'Queens', 'Jamaica Bay', 'Boro Zone')
# (168, 'Bronx', 'Mott Haven/Port Morris', 'Boro Zone')
# (159, 'Bronx', 'Melrose', 'Boro Zone')
# (126, 'Bronx', 'Hunts Point', 'Boro Zone')
# (147, 'Bronx', 'Longwood', 'Boro Zone')
# (199, 'Bronx', 'Rikers Island/North and South Brother Islands', 'Boro Zone')
# (167, 'Bronx', 'Morrisania/Concourse Village/Yankee Stadium/Macombs Dam Park', 'Boro Zone')
# (47, 'Bronx', 'Claremont/Bathgate', 'Boro Zone')
# (60, 'Bronx', 'Crotona Park East', 'Boro Zone')
# (59, 'Bronx', 'Crotona Park', 'Boro Zone')
# (69, 'Bronx', 'East Concourse/Concourse Village', 'Boro Zone')
# (119, 'Bronx', 'Highbridge', 'Boro Zone')
# (235, 'Bronx', 'University Heights/Morris Heights/Fordham Heights', 'Boro Zone')
# (169, 'Bronx', 'Mount Hope', 'Boro Zone')
# (32, 'Bronx', 'Bronxdale/West Farms', 'Boro Zone')
# (78, 'Bronx', 'East Tremont', 'Boro Zone')
# (20, 'Bronx', 'Belmont', 'Boro Zone')
# (18, 'Bronx', 'Bedford Park', 'Boro Zone')
# (174, 'Bronx', 'Norwood', 'Boro Zone')
# (241, 'Bronx', 'Van Cortlandt Village', 'Boro Zone')
# (153, 'Manhattan', 'Marble Hill', 'Boro Zone')
# (220, 'Bronx', 'Spuyten Duyvil/Kingsbridge', 'Boro Zone')
# (248, 'Bronx', 'West Farms/Bronx River', 'Boro Zone')
# (212, 'Bronx', 'Soundview/Bruckner/Clason Point/Soundview Park', 'Boro Zone')
# (213, 'Bronx', 'Soundview/Castle Hill/Unionpoint', 'Boro Zone')
# (182, 'Bronx', 'Parkchester', 'Boro Zone')
# (250, 'Bronx', 'Westchester Village/Unionport', 'Boro Zone')
# (208, 'Bronx', 'Schuylerville/Edgewater Park/Ferry Point Park/St. Raymond Cemetery', 'Boro Zone')
# (58, 'Bronx', 'Country Club', 'Boro Zone')
# (51, 'Bronx', 'Co-Op City', 'Boro Zone')
# (46, 'Bronx', 'City Island/Hard Island', 'Boro Zone')
# (185, 'Bronx', 'Pelham Parkway/Hutchison Metro Center', 'Boro Zone')
# (242, 'Bronx', 'Van Nest/Morris Park', 'Boro Zone')
# (3, 'Bronx', 'Allerton/Pelham Gardens', 'Boro Zone')
# (254, 'Bronx', 'Williamsbridge/Olinville', 'Boro Zone')
# (81, 'Bronx', 'Eastchester', 'Boro Zone')
# (259, 'Bronx', 'Woodlawn/Wakefield', 'Boro Zone')
# (240, 'Bronx', 'Van Cortlandt Park', 'Boro Zone')
# (31, 'Bronx', 'Bronx Park', 'Boro Zone')
# (184, 'Bronx', 'Pelham Bay Park', 'Boro Zone')
# (209, 'Manhattan', 'Seaport/Financial District/Battery Park City', 'Yellow Zone')
# (231, 'Manhattan', 'TriBeCa/Civic Center', 'Yellow Zone')
# (105, 'Manhattan', 'Liberty Island', 'Yellow Zone')
# (144, 'Manhattan', 'Little Italy/NoLiTa', 'Yellow Zone')
# (114, 'Manhattan', 'Greenwich Village South', 'Yellow Zone')
# (249, 'Manhattan', 'West Village', 'Yellow Zone')
# (232, 'Manhattan', 'Two Bridges/Seward Park', 'Yellow Zone')
# (148, 'Manhattan', 'Lower East Side', 'Yellow Zone')
# (79, 'Manhattan', 'East Village', 'Yellow Zone')
# (68, 'Manhattan', 'East Chelsea/Hudson Yards', 'Yellow Zone')
# (239, 'Manhattan', 'Upper West Side South/Hell’s Kitchen', 'Yellow Zone')
# (164, 'Manhattan', 'Midtown South', 'Yellow Zone')
# (163, 'Manhattan', 'Midtown North/Times Square', 'Yellow Zone')
# (224, 'Manhattan', 'Stuy Town/Peter Cooper Village', 'Yellow Zone')
# (107, 'Manhattan', 'Gramercy', 'Yellow Zone')
# (170, 'Manhattan', 'Murray Hill', 'Yellow Zone')
# (237, 'Manhattan', 'Upper East Side South/East Midtown/Turtle Bay/United Nations', 'Yellow Zone')
# (233, 'Manhattan', 'United Nations/Turtle Bay South', 'Yellow Zone')
# (238, 'Manhattan', 'Upper West Side North/Lincoln Square', 'Yellow Zone')
# (24, 'Manhattan', 'Bloomingdale/Upper West Side North', 'Yellow Zone')
# (151, 'Manhattan', 'Manhattan Valley', 'Yellow Zone')
# (202, 'Manhattan', 'Roosevelt Island', 'Boro Zone')
# (236, 'Manhattan', 'Upper East Side North/Carnegie Hill/Yorkville', 'Yellow Zone')
# (166, 'Manhattan', 'Morningside Heights', 'Boro Zone')
# (152, 'Manhattan', 'Manhattanville', 'Boro Zone')
# (116, 'Manhattan', 'Hamilton Heights', 'Boro Zone')
# (50, 'Manhattan', 'Clinton West/East Harlem (South)', 'Yellow Zone')
# (74, 'Manhattan', 'East Harlem North', 'Boro Zone')
# (48, 'Manhattan', 'Clinton East/East Harlem (North)', 'Yellow Zone')
# (194, 'Manhattan', 'Randalls Island', 'Yellow Zone')
# (244, 'Manhattan', 'Washington Heights South', 'Boro Zone')
# (243, 'Manhattan', 'Washington Heights North', 'Boro Zone')
# (127, 'Manhattan', 'Inwood', 'Boro Zone')
# (120, 'Manhattan', 'Highbridge Park', 'Boro Zone')
# (128, 'Manhattan', 'Inwood Hill Park', 'Boro Zone')
# (43, 'Manhattan', 'Central Park', 'Yellow Zone')
# (7, 'Queens', 'Astoria/(North)-Ditmars-Steinway', 'Boro Zone')
# (179, 'Queens', 'Old Astoria', 'Boro Zone')
# (260, 'Queens', 'Woodside/Calvary/Mount Zion Cemeteries', 'Boro Zone')
# (193, 'Queens', 'Queensbridge/Ravenswood', 'Boro Zone')
# (226, 'Queens', 'Sunnyside', 'Boro Zone')
# (207, 'Queens', 'Saint Michaels Cemetery/Woodside', 'Boro Zone')
# (8, 'Queens', 'Astoria Park', 'Boro Zone')
# (145, 'Queens', 'Long Island City/Hunters Point', 'Boro Zone')
# (129, 'Queens', 'Jackson Heights', 'Boro Zone')
# (70, 'Queens', 'East Elmhurst', 'Boro Zone')
# (173, 'Queens', 'North Corona', 'Boro Zone')
# (83, 'Queens', 'Elmhurst/Maspeth', 'Boro Zone')
# (56, 'Queens', 'Corona/Fresh Meadows', 'Boro Zone')
# (157, 'Queens', 'Maspeth/Mount Olivet/All Faiths Cemeteries', 'Boro Zone')
# (198, 'Queens', 'Ridgewood', 'Boro Zone')
# (102, 'Queens', 'Glendale/Highland Park', 'Boro Zone')
# (160, 'Queens', 'Middle Village/St. John Cemetery', 'Boro Zone')
# (196, 'Queens', 'Rego Park', 'Boro Zone')
# (95, 'Queens', 'Forest Hills', 'Boro Zone')
# (53, 'Queens', 'College Point', 'Boro Zone')
# (252, 'Queens', 'Whitestone', 'Boro Zone')
# (15, 'Queens', 'Bay Terrace/Fort Totten', 'Boro Zone')
# (73, 'Queens', 'East Flushing/Kissena Park', 'Boro Zone')
# (192, 'Queens', 'Queensboro Hill', 'Boro Zone')
# (253, 'Queens', 'Willets Point', 'Boro Zone')
# (135, 'Queens', 'Kew Gardens Hills', 'Boro Zone')
# (121, 'Queens', 'Hillcrest/Pomonok', 'Boro Zone')
# (98, 'Queens', 'Fresh Meadows', 'Boro Zone')
# (131, 'Queens', 'Jamaica Estates', 'Boro Zone')
# (28, 'Queens', 'Briarwood/Jamaica Hills', 'Boro Zone')
# (93, 'Queens', 'Flushing Meadows-Corona Park/Mount Hebron/Cedar Grove Cemeteries', 'Boro Zone')
# (175, 'Queens', 'Oakland Gardens/Cunningham Park', 'Boro Zone')
# (134, 'Queens', 'Kew Gardens', 'Boro Zone')
# (197, 'Queens', 'Richmond Hill', 'Boro Zone')
# (180, 'Queens', 'Ozone Park', 'Boro Zone')
# (258, 'Queens', 'Woodhaven', 'Boro Zone')
# (216, 'Queens', 'South Ozone Park', 'Boro Zone')
# (124, 'Queens', 'Howard Beach/Spring Creek Park', 'Boro Zone')
# (9, 'Queens', 'Auburndale', 'Boro Zone')
# (16, 'Queens', 'Bayside', 'Boro Zone')
# (64, 'Queens', 'Douglaston/Little Neck/Alley Pond Park', 'Boro Zone')
# (130, 'Queens', 'Jamaica', 'Boro Zone')
# (215, 'Queens', 'South Jamaica', 'Boro Zone')
# (10, 'Queens', 'Baisley Park', 'Boro Zone')
# (218, 'Queens', 'Springfield Gardens North', 'Boro Zone')
# (205, 'Queens', 'Saint Albans', 'Boro Zone')
# (122, 'Queens', 'Hollis', 'Boro Zone')
# (101, 'Queens', 'Glen Oaks', 'Boro Zone')
# (19, 'Queens', 'Bellerose', 'Boro Zone')
# (191, 'Queens', 'Queens Village', 'Boro Zone')
# (38, 'Queens', 'Cambria Heights', 'Boro Zone')
# (139, 'Queens', 'Laurelton', 'Boro Zone')
# (219, 'Queens', 'Springfield Gardens South', 'Boro Zone')
# (203, 'Queens', 'Rosedale', 'Boro Zone')
# (86, 'Queens', 'Far Rockaway', 'Boro Zone')
# (117, 'Queens', 'Hammels/Arverne', 'Boro Zone')
# (30, 'Queens', 'Broad Channel', 'Boro Zone')
# (201, 'Queens', 'Rockaway Park', 'Boro Zone')
# (138, 'Queens', 'LaGuardia Airport/East Elmhurst', 'Airports')
# (132, 'Queens', 'JFK Airport', 'Airports')
# (27, 'Queens', 'Breezy Point/Fort Tilden/Riis Beach', 'Boro Zone')
# (206, 'Staten Island', 'Saint George/New Brighton', 'Boro Zone')
# (221, 'Staten Island', 'Stapleton', 'Boro Zone')
# (13, 'Manhattan', 'Battery Park City', 'Yellow Zone')
# (251, 'Staten Island', 'Westerleigh', 'Boro Zone')
# (187, 'Staten Island', 'Port Richmond', 'Boro Zone')
# (156, 'Staten Island', 'Mariners Harbor', 'Boro Zone')
# (214, 'Staten Island', 'South Beach/Dongan Hills', 'Boro Zone')
# (172, 'Staten Island', 'New Dorp/Midland Beach', 'Boro Zone')
# (23, 'Staten Island', 'Bloomfield/Emerson Hill', 'Boro Zone')
# (99, 'Staten Island', 'Freshkills Park', 'Boro Zone')
# (176, 'Staten Island', 'Oakwood', 'Boro Zone')
# (84, 'Staten Island', "Eltingville/Annadale/Prince's Bay", 'Boro Zone')
# (5, 'Staten Island', 'Arden Heights', 'Boro Zone')
# (44, 'Staten Island', 'Charleston/Tottenville', 'Boro Zone')
# (6, 'Staten Island', 'Arrochar/Fort Wadsworth', 'Boro Zone')
# (110, 'Staten Island', 'Great Kills Park', 'Boro Zone')
# (1, 'EWR', 'Newark Airport', 'EWR')
# (4, 'Manhattan', 'Alphabet City/East Village', 'Yellow Zone')
# (12, 'Manhattan', 'Battery Park', 'Yellow Zone')
# (21, 'Brooklyn', 'Bensonhurst East', 'Boro Zone')
# (25, 'Brooklyn', 'Boerum Hill', 'Boro Zone')
# (41, 'Manhattan', 'Central Harlem (South)', 'Boro Zone')
# (42, 'Manhattan', 'Central Harlem North', 'Boro Zone')
# (45, 'Manhattan', 'Chinatown', 'Yellow Zone')
# (52, 'Brooklyn', 'Cobble Hill', 'Boro Zone')
# (54, 'Brooklyn', 'Columbia Street/Carrol Gardens', 'Boro Zone')
# (57, 'Queens', 'Corona', 'Boro Zone')
# (66, 'Brooklyn', 'DUMBO/Vinegar Hill', 'Boro Zone')
# (75, 'Manhattan', 'East Harlem South', 'Boro Zone')
# (82, 'Queens', 'Elmhurst', 'Boro Zone')
# (85, 'Brooklyn', 'Erasmus', 'Boro Zone')
# (87, 'Manhattan', 'Financial District North', 'Yellow Zone')
# (88, 'Manhattan', 'Financial District South', 'Yellow Zone')
# (90, 'Manhattan', 'Flatiron', 'Yellow Zone')
# (92, 'Queens', 'Flushing', 'Boro Zone')
# (94, 'Bronx', 'Fordham South', 'Boro Zone')
# (100, 'Manhattan', 'Garment District/Midtown Center', 'Yellow Zone')
# (103, 'Manhattan', "Governor's Island", 'Yellow Zone')
# (104, 'Manhattan', 'Ellis Island', 'Yellow Zone')
# (106, 'Brooklyn', 'Gowanus', 'Boro Zone')
# (109, 'Staten Island', 'Great Kills', 'Boro Zone')
# (113, 'Manhattan', 'Greenwich Village North', 'Yellow Zone')
# (115, 'Staten Island', 'Grymes Hill/Clifton', 'Boro Zone')
# (118, 'Staten Island', 'Heartland Village/Todt Hill', 'Boro Zone')
# (125, 'Manhattan', 'Hudson Sqare', 'Yellow Zone')
# (136, 'Bronx', 'Kingsbridge Heights', 'Boro Zone')
# (137, 'Manhattan', 'Kips Bay', 'Yellow Zone')
# (140, 'Manhattan', 'Lenox Hill East', 'Yellow Zone')
# (141, 'Manhattan', 'Lenox Hill West', 'Yellow Zone')
# (142, 'Manhattan', 'Lincoln Square East', 'Yellow Zone')
# (143, 'Manhattan', 'Lincoln Square West', 'Yellow Zone')
# (146, 'Queens', 'Long Island City/Queens Plaza', 'Boro Zone')
# (158, 'Manhattan', 'Meatpacking/West Village West', 'Yellow Zone')
# (161, 'Manhattan', 'Midtown Center', 'Yellow Zone')
# (162, 'Manhattan', 'Midtown East', 'Yellow Zone')
# (165, 'Brooklyn', 'Midwood', 'Boro Zone')
# (171, 'Queens', 'Murray Hill-Queens', 'Boro Zone')
# (183, 'Bronx', 'Pelham Bay', 'Boro Zone')
# (186, 'Manhattan', 'Penn Station/Madison Sqare West/Midtown South', 'Yellow Zone')
# (195, 'Brooklyn', 'Red Hook', 'Boro Zone')
# (200, 'Bronx', 'Riverdale/North Riverdale/Fieldston', 'Boro Zone')
# (204, 'Staten Island', 'Rossville/Woodrow', 'Boro Zone')
# (210, 'Brooklyn', 'Sheepshead Bay', 'Boro Zone')
# (211, 'Manhattan', 'SoHo', 'Yellow Zone')
# (223, 'Queens', 'Steinway', 'Boro Zone')
# (225, 'Brooklyn', 'Stuyvesant Heights', 'Boro Zone')
# (227, 'Brooklyn', 'Sunset Park East', 'Boro Zone')
# (229, 'Manhattan', 'Sutton Place/Turtle Bay North', 'Yellow Zone')
# (230, 'Manhattan', 'Times Sq/Theatre District', 'Yellow Zone')
# (234, 'Manhattan', 'Union Sqare', 'Yellow Zone')
# (245, 'Staten Island', 'West Brighton', 'Boro Zone')
# (246, 'Manhattan', 'West Chelsea/Hudson Yards', 'Yellow Zone')
# (247, 'Bronx', 'West Concourse', 'Boro Zone')
# (256, 'Brooklyn', 'Williamsburg (South Side)', 'Boro Zone')
# (261, 'Manhattan', 'World Trade Center/Midtown South', 'Yellow Zone')
# (262, 'Manhattan', 'Yorkville East', 'Yellow Zone')
# (263, 'Manhattan', 'Yorkville West', 'Yellow Zone')
# (264, 'Unknown', 'NV', 'N/A')
# (265, 'Unknown', 'NA', 'N/A')

# %% [markdown]
# In the last step we calculate the middle pin points of the polygons whom the taxi zone tuples are pointing to right now and add the three lists (taxi zone tuple list, polygon list and centrals list) to a geojson output.

# %%
print('Central point list:')
for c in nd.central_points():
    print(c)
nd.to_geojson('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/taxi_zones.geo.json')
# Out:
# Central point list:
# (-73.94774222479111, 40.72943730469232)
# (-73.95799521274463, 40.7146299981626)
# (-73.95542526634905, 40.70303150527341)
# (-73.93512570600026, 40.713531844483825)
# (-73.9949420738628, 40.694908632295586)
# (-73.98610052266547, 40.69469776397623)
# (-73.97363879405397, 40.69232668515191)
# (-73.96452416929192, 40.68898259421262)
# (-73.97899640763016, 40.70594713511322)
# (-73.94195070585454, 40.68708271672516)
# (-73.92615074293467, 40.70078203400203)
# (-73.9072806743975, 40.68787973931529)
# (-73.88480571559766, 40.68187911833201)
# (-73.88855595160125, 40.67269354456475)
# (-73.87768598391077, 40.66416512526354)
# (-73.88073201609768, 40.643446740247)
# (-73.8727349920846, 40.69485587062359)
# (-74.00583529237828, 40.676194328995926)
# (-73.97957587697884, 40.67220807084388)
# (-73.98214716476525, 40.657746462676435)
# (-74.01051464599202, 40.64835143930654)
# (-73.99116925479412, 40.652138273497314)
# (-73.96753716038879, 40.67747142549298)
# (-73.94272336814319, 40.67394740325123)
# (-73.93609667783608, 40.66679218182402)
# (-73.94593711355529, 40.65971804683574)
# (-74.02891183310439, 40.62732094164297)
# (-74.01856834990497, 40.614360123636764)
# (-73.99290805934723, 40.612403358960705)
# (-74.00733740515271, 40.604102519784924)
# (-73.98855598016888, 40.59000410945521)
# (-73.99521010775146, 40.63657243135266)
# (-73.97776520357893, 40.64159452838619)
# (-73.96545127001542, 40.620226120766816)
# (-73.98530675703724, 40.57667456740513)
# (-73.96054113765933, 40.5786910081146)
# (-73.96156062018008, 40.63923021181982)
# (-73.9676334492317, 40.598166429467106)
# (-73.94627987678166, 40.604918212053974)
# (-73.93715580502682, 40.58706737221091)
# (-73.91238393940927, 40.67685028610904)
# (-73.9108179354504, 40.663846220663196)
# (-73.94378581605895, 40.6440777963835)
# (-73.88283139105806, 40.660258605981724)
# (-73.9329016936351, 40.6262187740897)
# (-73.90433239602126, 40.607962602914384)
# (-73.88845687138027, 40.638567887951965)
# (-73.92052970508405, 40.58377200404262)
# (-73.96957409160663, 40.6608983084711)
# (-73.84648068378134, 40.58893486563477)
# (-73.91803532609231, 40.80815461123826)
# (-73.91400692753346, 40.81826194272558)
# (-73.8866074211074, 40.809880818565055)
# (-73.89606501077152, 40.821166341788626)
# (-73.8904538989398, 40.79601479566681)
# (-73.91595991605357, 40.8286076014429)
# (-73.9078523614524, 40.83966263447033)
# (-73.8884202701517, 40.831559877522196)
# (-73.89396770878606, 40.83838519774193)
# (-73.92084206237486, 40.82720633721194)
# (-73.92754799311325, 40.836912731559316)
# (-73.90665861968489, 40.858172045492545)
# (-73.90467078992305, 40.849875407653975)
# (-73.87643895835731, 40.842168104879384)
# (-73.89218488012555, 40.846955288910216)
# (-73.88792810553595, 40.85783121261824)
# (-73.89146279024025, 40.87314590717404)
# (-73.87914833766986, 40.87727467516326)
# (-73.89709297985544, 40.8790405950084)
# (-73.90569168627182, 40.881304826579324)
# (-73.90991233668186, 40.89402288768475)
# (-73.87208943930426, 40.829121539409584)
# (-73.86382252935368, 40.81488079940826)
# (-73.83879684839995, 40.82310645847335)
# (-73.85807803414131, 40.83776753895098)
# (-73.84510874946697, 40.83830457244178)
# (-73.823203699032, 40.81937057429918)
# (-73.78892702278499, 40.834969249385814)
# (-73.82494421175132, 40.87218861366009)
# (-73.91745300868995, 40.71705567824992)
# (-73.85047842611183, 40.849267442234336)
# (-73.84933760712705, 40.85241116451729)
# (-73.85419542281616, 40.86379181171661)
# (-73.8595410826934, 40.881168921296684)
# (-73.82700868248816, 40.88297621901508)
# (-73.86432705402038, 40.89411328835895)
# (-73.88453104950585, 40.897263585491395)
# (-73.87549225957561, 40.85835152184341)
# (-73.80461963273298, 40.841778478048774)
# (-74.0016447004499, 40.69489080698312)
# (-74.00859458305793, 40.717772119878134)
# (-74.01017054918847, 40.68514157757423)
# (-74.00403580980367, 40.72432088318132)
# (-73.99614197126137, 40.73058933043414)
# (-74.00791264867112, 40.73534643458651)
# (-73.99332959240294, 40.712812145744266)
# (-73.98175175185241, 40.705805497450044)
# (-73.96695502926265, 40.71821344369764)
# (-74.00385536953506, 40.75005809478554)
# (-73.99598470346939, 40.76595255781474)
# (-73.99025470368338, 40.7442278375399)
# (-73.98154135118445, 40.75758212240067)
# (-73.9767020118098, 40.7314951536173)
# (-73.98374963215493, 40.73713582834189)
# (-73.89317664730191, 40.7560337944926)
# (-73.96842536697929, 40.75587799155069)
# (-73.96731812277083, 40.75038026037943)
# (-73.98639789607532, 40.77523864141913)
# (-73.97738698539054, 40.78738214537905)
# (-73.96735438183946, 40.79922339403563)
# (-73.95765978316273, 40.74839899292225)
# (-73.94987142544738, 40.77759904946009)
# (-73.96154912438098, 40.809297201094886)
# (-73.9549158432786, 40.8191308140898)
# (-73.94889435458364, 40.826868848570456)
# (-73.9476402244803, 40.79731083761565)
# (-73.94156017857563, 40.819576764219214)
# (-73.93850580518557, 40.80205928562985)
# (-73.92524914714092, 40.79084197352329)
# (-73.94136969572799, 40.84187990924376)
# (-73.93472478034876, 40.856106426761286)
# (-73.92193606137886, 40.856207607705635)
# (-73.93063285679249, 40.84626168181519)
# (-73.921719723602, 40.87273252935779)
# (-73.96549919797933, 40.78253515317078)
# (-73.9131836315311, 40.771440358975056)
# (-73.93131025253841, 40.77209846203066)
# (-73.90710036005157, 40.74476623878846)
# (-73.93644375633099, 40.758405399350465)
# (-73.92552517841314, 40.74648016204618)
# (-73.89903124469245, 40.764289361804)
# (-73.92312975054324, 40.778554972829106)
# (-73.94938642148819, 40.74482011060784)
# (-73.88489828291021, 40.75514668156584)
# (-73.87129232043404, 40.7634347724999)
# (-73.86291055930255, 40.754206102065844)
# (-73.88214667116361, 40.73973071063485)
# (-73.85791170157171, 40.743841318800754)
# (-73.90014954706288, 40.720118511898654)
# (-73.9043803182959, 40.70645821863044)
# (-73.87733361783725, 40.702341637055014)
# (-73.87663350839239, 40.71414370308744)
# (-73.86353939569268, 40.72650249970593)
# (-73.8477976112127, 40.72185340119573)
# (-73.83925660351937, 40.765703622066596)
# (-73.8099221460439, 40.78972565899067)
# (-73.7812902024022, 40.786695401683005)
# (-73.80687583976868, 40.74930543719483)
# (-73.81622923828543, 40.74236110097999)
# (-73.83161009033616, 40.759420258472865)
# (-73.82048494967152, 40.72619110471072)
# (-73.8031744900834, 40.727746615004946)
# (-73.78821708308962, 40.734939831414636)
# (-73.77541797121756, 40.72120775703328)
# (-73.80802254205544, 40.71248600388505)
# (-73.83673038630414, 40.739745351483286)
# (-73.76106004310249, 40.7360027656425)
# (-73.82994425018259, 40.70786168634206)
# (-73.82836048409195, 40.694423301025495)
# (-73.8490854212883, 40.67989502920889)
# (-73.85666721674734, 40.69205328268736)
# (-73.82103490333975, 40.67664564102542)
# (-73.85968029553112, 40.65377951397798)
# (-73.78725958398438, 40.75453175905223)
# (-73.7645976770893, 40.76169638796015)
# (-73.86502856810401, 40.72532705305162)
# (-73.79197154018492, 40.70490422186499)
# (-73.79123022367365, 40.6940414066197)
# (-73.78857003298727, 40.6803798938023)
# (-73.97470546536898, 40.63701138395315)
# (-73.76372247342846, 40.693792505466966)
# (-73.7636461505032, 40.7116394118987)
# (-73.71385743097503, 40.74708622365839)
# (-73.91234036709469, 40.65182692765207)
# (-73.74251148944006, 40.71641943271577)
# (-73.73753928355256, 40.694587215132856)
# (-73.74411089815074, 40.67639278605391)
# (-73.76871727259702, 40.66191569434523)
# (-73.73890685592752, 40.65344042301179)
# (-73.75710710546609, 40.60179760286557)
# (-73.79683152638438, 40.59242567050431)
# (-73.90677909884062, 40.5624138774715)
# (-73.77470352527715, 40.600849732838356)
# (-73.87209440351441, 40.77482389784106)
# (-73.74699532670846, 40.63755689077682)
# (-73.89981629019434, 40.55975897205464)
# (-74.09336354452992, 40.636976126867864)
# (-74.07777671148109, 40.62716150404967)
# (-74.07236686634324, 40.61273858845821)
# (-74.1263874196644, 40.616900736370106)
# (-74.13057452506335, 40.633649014064105)
# (-74.15960821981288, 40.642993852726796)
# (-74.08117475983923, 40.59251057695362)
# (-74.10058184012614, 40.57282090370382)
# (-74.13125317578832, 40.58897660349485)
# (-74.18866971291553, 40.57537541312148)
# (-74.12371720307581, 40.56266684217244)
# (-74.17282067303134, 40.53812212776284)
# (-74.19664703284157, 40.55293258278259)
# (-74.23391132750132, 40.5292081842251)
# (-74.05891612400343, 40.60157583628745)
# (-74.12941146072883, 40.54281198083484)
# (-74.18003, 40.68883)
# (-73.96695502926265, 40.71821344369764)
# (-74.0016447004499, 40.69489080698312)
# (-73.99290805934723, 40.612403358960705)
# (-73.98610052266547, 40.69469776397623)
# (-73.94484966411764, 40.790128698381416)
# (-73.93850580518557, 40.80205928562985)
# (-73.99332959240294, 40.712812145744266)
# (-74.00583529237828, 40.676194328995926)
# (-74.00583529237828, 40.676194328995926)
# (-73.85791170157171, 40.743841318800754)
# (-73.98610052266547, 40.69469776397623)
# (-73.94484966411764, 40.790128698381416)
# (-73.88214667116361, 40.73973071063485)
# (-73.95011183461277, 40.648755920254324)
# (-74.0016447004499, 40.69489080698312)
# (-74.0016447004499, 40.69489080698312)
# (-73.99025470368338, 40.7442278375399)
# (-73.83161009033616, 40.759420258472865)
# (-73.89892903537171, 40.85870858595671)
# (-73.99025470368338, 40.7442278375399)
# (-74.01017054918847, 40.68514157757423)
# (-74.01017054918847, 40.68514157757423)
# (-74.00583529237828, 40.676194328995926)
# (-74.14959763136125, 40.54851643274651)
# (-73.99614197126137, 40.73058933043414)
# (-74.07777671148109, 40.62716150404967)
# (-74.13125317578832, 40.58897660349485)
# (-74.00403580980367, 40.72432088318132)
# (-73.89709297985544, 40.8790405950084)
# (-73.97557701086284, 40.74313358341563)
# (-73.95765978316273, 40.74839899292225)
# (-73.95765978316273, 40.74839899292225)
# (-73.98639789607532, 40.77523864141913)
# (-73.98639789607532, 40.77523864141913)
# (-73.94938642148819, 40.74482011060784)
# (-74.00791264867112, 40.73534643458651)
# (-73.99025470368338, 40.7442278375399)
# (-73.99025470368338, 40.7442278375399)
# (-73.97585712471457, 40.6197966406535)
# (-73.97557701086284, 40.74313358341563)
# (-73.78892702278499, 40.834969249385814)
# (-73.99025470368338, 40.7442278375399)
# (-74.00583529237828, 40.676194328995926)
# (-73.90991233668186, 40.89402288768475)
# (-74.19664703284157, 40.55293258278259)
# (-73.93715580502682, 40.58706737221091)
# (-74.00403580980367, 40.72432088318132)
# (-73.90344942046345, 40.77837151633432)
# (-73.95193783454589, 40.68825839477922)
# (-73.99933095957388, 40.640612074834124)
# (-73.96842536697929, 40.75587799155069)
# (-73.98154135118445, 40.75758212240067)
# (-73.99025470368338, 40.7442278375399)
# (-74.08228966025433, 40.642338570753545)
# (-74.00385536953506, 40.75005809478554)
# (-73.92084206237486, 40.82720633721194)
# (-73.95799521274463, 40.7146299981626)
# (-73.99025470368338, 40.7442278375399)
# (-73.93856857679717, 40.7804584723767)
# (-73.93856857679717, 40.7804584723767)
# (-73.99562, 40.54999)
# (-73.99562, 40.54999)

# %% [markdown]
# Seventh Excercise: Load and add the generated geojson layer to the map, which contains the taxi zones. Link it to the taxi usage over the most recent month parsed in exercise 3 and show it on the map by using lines between the neighbourhood center pinpoints. Add an extra variable to save yellow and green to the read_taxidata.py

# %% [markdown]
# First print generated taxi zone geojson

# %%
#center to New York at 41 degrees north and 74 degrees west
m = leafmap.Map(google_map="HYBRID",center=[40.702557, -74.012318], zoom=12,height="600px", width="1200px",max_zoom="20")  #center=[lat, lon]
#show
print('Showing current layer names before adding neighbourhoods:')
print(m.get_layer_names())
print('Random color hex list:')
r = lambda: random.randint(0,255)
color_list: List[str] = []
for i in range(0, len(tz.zones)):
    color_list.append('#%02X%02X%02X' % (r(), r(), r()))
print('Add geojson layer neighbourhoods, color is sorted by geojson polygon order:')
m.add_geojson('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/nyc-neighborhoods.geo.json', layer_name='neighbourhoods', style={}, hover_style={}, style_callback=None, fill_colors=color_list, info_mode='on_hover')
m.layer_opacity('neighbourhoods', 0.3)
color_list: List[str] = []
for i in range(0, len(nd.input_geojson['features'])):
    color_list.append('#%02X%02X%02X' % (r(), r(), r()))
print('Add geojson layer neighbourhoods, color is sorted by geojson polygon order:')
m.add_geojson('/home/benjamin-elias/PycharmProjects/Proseminar Jupyter-Leafmap/taxi_zones.geo.json', layer_name='taxi_zones', style={}, hover_style={}, style_callback=None, fill_colors=color_list, info_mode='on_hover')
m.layer_opacity('taxi_zones', 0.8)
print(m.get_layer_names())
m
# Out:
# Showing current layer names before adding neighbourhoods:
# ['OpenStreetMap', 'Google Satellite']
# Random color hex list:
# Add geojson layer neighbourhoods, color is sorted by geojson polygon order:
# ['OpenStreetMap', 'Google Satellite', 'taxi_zones']
# Map(center=[40.702557, -74.012318], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Eighth Excercise: Add a time widget to the map so you can select date and time. The widget is limited to the minimal and the maximum time found within the folder "taxi_data".

# %% [markdown]
# Ninth Excercise: Efficiently parse the time from taxi_data from the datasets available. On change the time frame is checked, when shrinked time sets are popped and removed, when increased, time sets are pushed to front or to the back and drawn to the map. Also upgrade the interconnections between the neighbourhoods within this timeframe.

# %% [markdown]
# Tenth Excercise: Add a heatmap containing the colors blue for start destination and red for target destination and draw them as a mixed color into the neighbourhoods into a new layer below the lines layer showing the interconnections. The intensity of the colors should be in comparison to the overall count of starts and arrivals for each neighbourhood.

# %% [markdown]
# Eleventh Exercise: Add a time filter widget so we can only see time sets from certain daytimes within the overall time range.

# %% [markdown]
# Twelveth Exercise: Add a passenger filter that can limit the passenger count within ranges. Refer minimum and maximum from values found. Repeat that with the taxi color and the vendor ID.

# %% [markdown]
# Thirteenth Excercise: Add a filter that can limit the distance moved count within ranges. Refer minimum and maximum from values found.

# %% [markdown]
# Fourteenth Excercise: Add a filter that can limit the money spent on the trip within ranges. Refer minimum and maximum from values found.

# %% [markdown]
# Fifteenth Excercise: Add a filter that can limit the neighbourhoods either on start (S) or arrival (A) using one string for mode and one string separated with commas to list the neighbourhoods. If anything is empty the filter is off.

# %% [markdown]
# Sixteenth Excercise: Add a filter that can select the payment type on the trip. Refer values available.

# %% [markdown]
# Seventeenth Excercise: Add tooltips that are highlighted on mouse hover within the borders of each neighbourhood that show the summarized and average data over the csv files always separated on start and arrival point like money spent, payment method, distance traveled and time per distance. The tooltip may contain a barchart showing the average count of starts and arrivals within the chosen daytime.
